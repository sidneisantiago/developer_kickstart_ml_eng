# %%
from scipy import _lib

# %%
import sklearn

sklearn.show_versions()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/python-eml-np9AbOMQ-py3.10/lib/python3.10/site-packages/scipy/__init__.py:192, in __getattr__(name)
#     191 try:
# --> 192     return globals()[name]
#     193 except KeyError:
#
# KeyError: '_lib'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import sklearn
#       3 sklearn.show_versions()
#
# File ~/Library/Caches/pypoetry/virtualenvs/python-eml-np9AbOMQ-py3.10/lib/python3.10/site-packages/sklearn/__init__.py:83
#      69     # We are not importing the rest of scikit-learn during the build
#      70     # process, as it may not be compiled yet
#      71 else:
#    (...)
# ...

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Caches/pypoetry/virtualenvs/python-eml-np9AbOMQ-py3.10/lib/python3.10/site-packages/scipy/__init__.py:192, in __getattr__(name)
#     191 try:
# --> 192     return globals()[name]
#     193 except KeyError:
#
# KeyError: '_lib'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 3
#       1 import pandas as pd
# ----> 3 from sklearn.model_selection import train_test_split
#
# File ~/Library/Caches/pypoetry/virtualenvs/python-eml-np9AbOMQ-py3.10/lib/python3.10/site-packages/sklearn/__init__.py:83
#      69     # We are not importing the rest of scikit-learn during the build
#      70     # process, as it may not be compiled yet
#      71 else:
#    (...)
# ...

# %%
df = pd.read_csv('../data/clean_housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20637    -121.09     39.48                25.0       1665.0           374.0
# 20638    -121.21     39.49                18.0        697.0           150.0
# 20639    -121.22     39.43                17.0       2254.0           485.0
# 20640    -121.32     39.43                18.0       1860.0           409.0
# 20641    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df_ml = df.copy()

# %%
df_ml.ocean_proximity = df.ocean_proximity.replace({'NEAR BAY': 0, 
                                    '<1H OCEAN': 1, 
                                    'INLAND': 2, 
                                    'NEAR OCEAN': 3,
                                    'ISLAND':4})

# %%
df_ml
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20637    -121.09     39.48                25.0       1665.0           374.0
# 20638    -121.21     39.49                18.0        697.0           150.0
# 20639    -121.22     39.43                17.0       2254.0           485.0
# 20640    -121.32     39.43                18.0       1860.0           409.0
# 20641    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df_ml.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
df_X = df_ml[['housing_median_age', 'total_rooms',
       'total_bedrooms', 'population', 'households', 'median_income', 'ocean_proximity']]
df_y = df_ml['median_house_value']

# %%
df_X
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    41.0        880.0           129.0       322.0
# 1                    21.0       7099.0          1106.0      2401.0
# 2                    52.0       1467.0           190.0       496.0
# 3                    52.0       1274.0           235.0       558.0
# 4                    52.0       1627.0           280.0       565.0
# ...                   ...          ...             ...         ...
# 20637                25.0       1665.0           374.0       845.0
# 20638                18.0        697.0           150.0       356.0
# 20639                17.0       2254.0           485.0      1007.0
# 20640                18.0       1860.0           409.0       741.0
# 20641                16.0       2785.0           616.0      1387.0
#
#        households  median_income  ocean_proximity
# 0           126.0         8.3252                0
# 1          1138.0         8.3014                0
# ...

# %%
df_y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20637     78100.0
# 20638     77100.0
# 20639     92300.0
# 20640     84700.0
# 20641     89400.0
# Name: median_house_value, Length: 20642, dtype: float64

# %%
# Splitting the data into train and test
X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, train_size=0.2, random_state=9,
                                                     shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Splitting the data into train and test
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(df_X, df_y, train_size=0.2, random_state=9,
#       3                                                      shuffle=True)
#
# NameError: name 'train_test_split' is not defined

# %%
X_test
